# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/listings.csv')

print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (22933, 79)
#       id                         listing_url       scrape_id last_scraped  \
# 0  23986  https://www.airbnb.com/rooms/23986  20250922033939   2025-09-24
# 1  40470  https://www.airbnb.com/rooms/40470  20250922033939   2025-09-24
# 2  46536  https://www.airbnb.com/rooms/46536  20250922033939   2025-09-24
# 3  84741  https://www.airbnb.com/rooms/84741  20250922033939   2025-09-24
# 4  88130  https://www.airbnb.com/rooms/88130  20250922033939   2025-09-24
#
#             source                                        name  \
# 0      city scrape             " Characteristic Milanese flat"
# 1  previous scrape         Giacinto Cosy & clean flat near MM1
# 2      city scrape                 Nico & Cinzia's Pink Suite!
# 3      city scrape             Nice room with private bathroom
# 4      city scrape  Great comfortable & quite APT. x 4 people!
#
#                                          description  \
# 0  I look forward to welcoming you in my flat; it...
# 1                                                NaN
# 2  Over the international fair in April we rent f...
# 3  Independent room with private bathroom.<br />C...
# 4  Our bright and comfortable apartment for 3+ 1 ...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  Flat  It's located in north side of milan, jus...
# 3  It may seem a peripheral zone and bare, but ju...
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/623d63f8-56cf...    95941  ...
# 1  https://a0.muscache.com/pictures/891684/01c17b...   174203  ...
# 2  https://a0.muscache.com/pictures/4eb8e0f5-e17b...   138683  ...
# 3  https://a0.muscache.com/pictures/0b34089b-4d58...   443989  ...
# 4  https://a0.muscache.com/pictures/606790/408e10...   481475  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.73                   4.69                4.46
# 1                        4.88                   4.45                4.52
# 2                        4.92                   4.34                4.58
# 3                        4.88                   4.18                4.64
# 4                        5.00                   4.43                4.71
#
#                                             license instant_bookable  \
# 0                                               NaN                f
# 1                                IT015146C2YDCLSU8G                f
# 2                                IT015209C2BBKGCMT7                f
# 3  I applied for a CIN, but haven’t received it yet                f
# 4                                               NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              2                                           2
# 2                              1                                           1
# 3                              3                                           1
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.16
# 1                                           0              0.24
# 2                                           0              0.23
# 3                                           0              3.94
# 4                                           0              0.04
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Missing values

# %%
print(df.isnull().sum())

missing = (df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
missing_df = missing[missing > 0].round(2).to_frame(name='missing_%')
print(missing_df)
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               3422
# Length: 79, dtype: int64
#                               missing_%
# neighbourhood_group_cleansed     100.00
# calendar_updated                 100.00
# host_neighbourhood                67.75
# neighbourhood                     53.58
# neighborhood_overview             53.58
# host_about                        46.50
# host_location                     20.84
# host_response_time                15.45
# host_response_rate                15.45
# review_scores_value               14.93
# review_scores_cleanliness         14.93
# review_scores_communication       14.93
# review_scores_location            14.93
# review_scores_accuracy            14.93
# review_scores_checkin             14.93
# first_review                      14.92
# reviews_per_month                 14.92
# last_review                       14.92
# review_scores_rating              14.92
# license                           13.94
# beds                              10.45
# price                             10.44
# estimated_revenue_l365d           10.44
# bathrooms                         10.33
# host_acceptance_rate               7.88
# host_is_superhost                  4.30
# bedrooms                           2.26
# description                        1.97
# has_availability                   0.81
# maximum_maximum_nights             0.05
# minimum_maximum_nights             0.05
# maximum_minimum_nights             0.05
# minimum_minimum_nights             0.05
# bathrooms_text                     0.04
# host_listings_count                0.01
# host_identity_verified             0.01
# host_picture_url                   0.01
# host_thumbnail_url                 0.01
# host_total_listings_count          0.01
# host_has_profile_pic               0.01
# host_name                          0.01
# host_since                         0.01
# host_verifications                 0.01

# %% [markdown]
# ## Inspect the price column

# %%
print(df['price'].dtype)
print(df['price'].head(10))
print(f"\nNull prices: {df['price'].isnull().sum()}")
# Out:
# object
# 0    $180.00
# 1        NaN
# 2     $86.00
# 3     $36.00
# 4    $250.00
# 5     $80.00
# 6     $63.00
# 7     $60.00
# 8    $143.00
# 9     $71.00
# Name: price, dtype: object
#
# Null prices: 2395
